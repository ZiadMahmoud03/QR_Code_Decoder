# %% [markdown]
# ## *Test Cv*

# %%
import cv2
import urllib
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode

# %%
test_image= cv2.imread('/content/drive/MyDrive/Cv_Test Cases/10.png')
test_image= cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
plt.imshow(test_image, cmap='gray')

# %%
hist = cv2.calcHist([test_image], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
# Apply histogram equalization
equ_image = cv2.equalizeHist(test_image)

# Display the original and equalized images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(test_image, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(equ_image, cmap='gray')
plt.title('Equalized Image')

plt.show()

# %%
hist1 = cv2.calcHist([equ_image], [0], None, [256], [0, 256])
plt.plot(hist1)

# %%
# Apply Median filter
filtered_image = cv2.medianBlur(equ_image, 9)  # Adjust the kernel size as needed

# Apply Binary Thresholding
_, thresholded_image = cv2.threshold(filtered_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(thresholded_image, cmap='gray')

# %%
fig = plt.figure(figsize=(20, 20))
for i in range(3, 50, 1):
    if i % 2 == 0 or i == 1:
        continue

    blurred_image = cv2.medianBlur(gray, i)

    fig.add_subplot(10, 10, i)

    plt.title(f"Kernel size: {i}")

    # Remove ticks
    plt.xticks([])
    plt.yticks([])

    plt.imshow(blurred_image, cmap="gray")

plt.show()
